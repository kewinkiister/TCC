# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

df = pd.read_csv ('Dados_Kewin/Dir.csv')
a=df.values;
Theta = df.iloc[:, 4:5];
Theta = Theta.values;
Gain = df.iloc[:, 5:6];
Gain = Gain.values;
#Gain = 10*np.log(Gain);
N_amostras=1801;
Theta = Theta.reshape(-1, N_amostras);
Gain = Gain.reshape(-1, N_amostras);

# %%
def find_3db_opening(array1, array2):
    value= array1.max()-3
    array1 = np.asarray(array1)
    idx = (np.abs(array1 - value)).argmin()
    return 2*(90-array2[idx])

# %%
print(max(Gain[0]))
# Out:
# -2.4281171221670204

# %%
def find_SLL(array1):
    i=1;
    j=1;
    SSL=[]
    SSLM=0
    while i<=(len(array1)-2):
        if(array1[i-1]<array1[i] and array1[i]>array1[i+1]):
            SSL.append(array1[i])                    
        i=i+1;       
    max1=max(SSL);
    SSL.remove(max1);
    max2=max(SSL);
    SSLM=max1-max2;
        
    return SSLM

# %%
i=0;
b=0;
Lambda=[]
d1d2=[]
bandwidth=[]
directivity=[]
sidelobel=[]
fig, ax = plt.subplots()
while i<len(df):
    ax.plot(Theta[b], Gain[b])
    print('----------------------------------------------------')
    print('N. of lambda d1={} and d1/d2={}'.format(a[i,1],a[i,3]))
    Lambda.append(a[i,1])
    d1d2.append(a[i,3])
    print('3 dB bandwidth = {}'.format(abs(find_3db_opening(Gain[b], Theta[b]))))  
    bandwidth.append(abs(find_3db_opening(Gain[b], Theta[b])))
    print('Directivity Plan H dB= {}'.format(max(Gain[b])))
    directivity.append(max(Gain[b]))
    print('Side Lobe Level = {}'.format(find_SLL(Gain[b]))) 
    sidelobel.append(find_SLL(Gain[b]))
    i = i+ N_amostras
    b=b+1
#plt.legend(('Num. de Lâmbdas='+str(a[i,1])),loc='upper right')
plt.legend(('Num. de Lâmbdas='+str(a[1,1]),'Num. de Lâmbdas='+str(a[1803,1]),'Num. de Lâmbdas='+str(a[3607,1])),loc='upper right')
plt.ylabel('Ganho(dB)')
plt.xlabel('Ângulo Theta(\u00B0)')
# Out:
# ----------------------------------------------------
# N. of lambda d1=5.0 and d1/d2=0.6
# 3 dB bandwidth = 11.599999999999994
# Directivity Plan H dB= -2.4281171221670204
# Side Lobe Level = 9.325873406851315e-15
# ----------------------------------------------------
# N. of lambda d1=6.0 and d1/d2=0.6
# 3 dB bandwidth = 165.2
# Directivity Plan H dB= -0.17069790530276
# Side Lobe Level = 1.9984014443252818e-15
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=0.6
# 3 dB bandwidth = 139.2
# Directivity Plan H dB= -2.56271163712737
# Side Lobe Level = 0.0
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=0.7
# 3 dB bandwidth = 137.39999999999998
# Directivity Plan H dB= -1.4982117482382602
# Side Lobe Level = 0.0
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=0.8
# 3 dB bandwidth = 109.4
# Directivity Plan H dB= -1.88270102969994
# Side Lobe Level = 1.9984014443252818e-14
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=0.9
# 3 dB bandwidth = 117.6
# Directivity Plan H dB= -1.6033342259111398
# Side Lobe Level = 1.9984014443252818e-14
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.0
# 3 dB bandwidth = 124.80000000000001
# Directivity Plan H dB= -1.4622600354903201
# Side Lobe Level = 2.9976021664879227e-14
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.1
# 3 dB bandwidth = 116.2
# Directivity Plan H dB= -1.37151052863395
# Side Lobe Level = 9.992007221626409e-15
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.2
# 3 dB bandwidth = 131.8
# Directivity Plan H dB= -1.19213118739138
# Side Lobe Level = 2.9753977059954195e-14
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.3
# 3 dB bandwidth = 164.2
# Directivity Plan H dB= -1.09593271222263
# Side Lobe Level = 1.021405182655144e-14
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.4
# 3 dB bandwidth = 163.60000000000002
# Directivity Plan H dB= -1.15106226526795
# Side Lobe Level = 2.9976021664879227e-14
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.5
# 3 dB bandwidth = 163.60000000000002
# Directivity Plan H dB= -1.1345688720274498
# Side Lobe Level = 9.992007221626409e-15
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.6
# 3 dB bandwidth = 113.6
# Directivity Plan H dB= -1.14783382327072
# Side Lobe Level = 0.0
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.7
# 3 dB bandwidth = 137.8
# Directivity Plan H dB= -1.01458822946681
# Side Lobe Level = 9.769962616701378e-15
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.8
# 3 dB bandwidth = 162.8
# Directivity Plan H dB= -1.22119445231585
# Side Lobe Level = 9.992007221626409e-15
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.9
# 3 dB bandwidth = 139.0
# Directivity Plan H dB= -1.08545728014418
# Side Lobe Level = 1.9984014443252818e-14
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=2.0
# 3 dB bandwidth = 136.8
# Directivity Plan H dB= -1.30133870232919
# Side Lobe Level = 0.0
# ----------------------------------------------------
# N. of lambda d1=8.0 and d1/d2=0.6
# 3 dB bandwidth = 164.39999999999998
# Directivity Plan H dB= 0.0119627664663261
# Side Lobe Level = 1.4399939574083476e-14
# ----------------------------------------------------
# N. of lambda d1=9.0 and d1/d2=0.6
# 3 dB bandwidth = 178.2
# Directivity Plan H dB= -1.6706243881429699
# Side Lobe Level = 0.0
# ----------------------------------------------------
# N. of lambda d1=10.0 and d1/d2=0.6
# 3 dB bandwidth = 154.0
# Directivity Plan H dB= -0.5275564076508711
# Side Lobe Level = 1.6986412276764895e-14
# ----------------------------------------------------
# N. of lambda d1=11.0 and d1/d2=0.6
# 3 dB bandwidth = 167.6
# Directivity Plan H dB= -0.606407852787781
# Side Lobe Level = 7.993605777301127e-15
# ----------------------------------------------------
# N. of lambda d1=12.0 and d1/d2=0.6
# 3 dB bandwidth = 174.4
# Directivity Plan H dB= -1.76237782975281
# Side Lobe Level = 9.992007221626409e-15
# ----------------------------------------------------
# N. of lambda d1=13.0 and d1/d2=0.6
# 3 dB bandwidth = 172.2
# Directivity Plan H dB= 1.24841289616977
# Side Lobe Level = 9.769962616701378e-15
# ----------------------------------------------------
# N. of lambda d1=14.0 and d1/d2=0.6
# 3 dB bandwidth = 176.4
# Directivity Plan H dB= -0.93208488389441
# Side Lobe Level = 1.199040866595169e-14
# ----------------------------------------------------
# N. of lambda d1=15.0 and d1/d2=0.6
# 3 dB bandwidth = 172.8
# Directivity Plan H dB= 3.5799190833911902
# Side Lobe Level = 0.0
# ----------------------------------------------------
# N. of lambda d1=5.0 and d1/d2=0.6
# 3 dB bandwidth = 10.599999999999994
# Directivity Plan H dB= 15.367240006721802
# Side Lobe Level = 13.992528704240552
# ----------------------------------------------------
# N. of lambda d1=6.0 and d1/d2=0.6
# 3 dB bandwidth = 8.800000000000011
# Directivity Plan H dB= 16.3629366721684
# Side Lobe Level = 13.97949814158935
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=0.6
# 3 dB bandwidth = 7.599999999999994
# Directivity Plan H dB= 17.158240665194
# Side Lobe Level = 14.18074816334523
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=0.7
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.5815397381048
# Side Lobe Level = 14.041765359322191
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=0.8
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.667868008110197
# Side Lobe Level = 13.818949954646888
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=0.9
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.6602480490261
# Side Lobe Level = 13.533064211990542
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.0
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.703167944871602
# Side Lobe Level = 13.813070649579442
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.1
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.672795988901697
# Side Lobe Level = 13.899584092446919
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.2
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.786307631111697
# Side Lobe Level = 13.683804774526298
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.3
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.8270194131455
# Side Lobe Level = 13.522671766823091
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.4
# 3 dB bandwidth = 7.199999999999989
# Directivity Plan H dB= 17.712877096451898
# Side Lobe Level = 13.277933166018869
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.5
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.697332394918
# Side Lobe Level = 13.042060716795481
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.6
# 3 dB bandwidth = 7.199999999999989
# Directivity Plan H dB= 17.6136050456442
# Side Lobe Level = 13.42732253761753
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.7
# 3 dB bandwidth = 7.199999999999989
# Directivity Plan H dB= 17.5819720280767
# Side Lobe Level = 12.93947537626675
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.8
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.744345411033603
# Side Lobe Level = 13.416212834422204
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=1.9
# 3 dB bandwidth = 7.199999999999989
# Directivity Plan H dB= 17.696775444883198
# Side Lobe Level = 13.353615805580008
# ----------------------------------------------------
# N. of lambda d1=7.0 and d1/d2=2.0
# 3 dB bandwidth = 7.400000000000006
# Directivity Plan H dB= 17.780572526342898
# Side Lobe Level = 13.369704004669348
# ----------------------------------------------------
# N. of lambda d1=8.0 and d1/d2=0.6
# 3 dB bandwidth = 6.599999999999994
# Directivity Plan H dB= 17.8323124243097
# Side Lobe Level = 13.870092738425589
# ----------------------------------------------------
# N. of lambda d1=9.0 and d1/d2=0.6
# 3 dB bandwidth = 5.800000000000011
# Directivity Plan H dB= 18.3492516325411
# Side Lobe Level = 14.008205522939381
# ----------------------------------------------------
# N. of lambda d1=10.0 and d1/d2=0.6
# 3 dB bandwidth = 5.199999999999989
# Directivity Plan H dB= 18.895075187485602
# Side Lobe Level = 14.403539213217304
# ----------------------------------------------------
# N. of lambda d1=11.0 and d1/d2=0.6
# 3 dB bandwidth = 4.800000000000011
# Directivity Plan H dB= 19.2257718217467
# Side Lobe Level = 14.31894845958045
# ----------------------------------------------------
# N. of lambda d1=12.0 and d1/d2=0.6
# 3 dB bandwidth = 4.400000000000006
# Directivity Plan H dB= 19.6492631763333
# Side Lobe Level = 14.37927639891878
# ----------------------------------------------------
# N. of lambda d1=13.0 and d1/d2=0.6
# 3 dB bandwidth = 4.0
# Directivity Plan H dB= 19.9834418272146
# Side Lobe Level = 14.498444995590102
# ----------------------------------------------------
# N. of lambda d1=14.0 and d1/d2=0.6
# 3 dB bandwidth = 3.8000000000000114
# Directivity Plan H dB= 20.3020842399035
# Side Lobe Level = 14.12947665827533
# ----------------------------------------------------
# N. of lambda d1=15.0 and d1/d2=0.6
# 3 dB bandwidth = 3.4000000000000057
# Directivity Plan H dB= 20.6122814682032
# Side Lobe Level = 14.46106034108359
# Text(0.5, 0, 'Ângulo Theta(°)')

# %%
Data1 = {'Num. de Lamb ': Lambda,
        'Rel. D1/D2': d1d2,
        '3dB bandwidth': bandwidth,
        'Dir Plan H dB': directivity,
        'Side Lobe Level': sidelobel         
        }
df1 = pd.DataFrame(Data1, columns = ['Num. de Lamb ', 'Rel. D1/D2', '3dB bandwidth', 'Dir Plan H dB', 'Side Lobe Level'])
df1.to_csv (r'/Users/kewinkuster/Documents/GitHub/TCC/Dados_Kewin/ExportData.csv', index = False, header=True)

print(df1)
# Out:
#     Num. de Lamb   Rel. D1/D2  3dB bandwidth  Dir Plan H dB  Side Lobe Level
# 0             5.0         0.6           11.6      -2.428117     9.325873e-15
# 1             6.0         0.6          165.2      -0.170698     1.998401e-15
# 2             7.0         0.6          139.2      -2.562712     0.000000e+00
# 3             7.0         0.7          137.4      -1.498212     0.000000e+00
# 4             7.0         0.8          109.4      -1.882701     1.998401e-14
# 5             7.0         0.9          117.6      -1.603334     1.998401e-14
# 6             7.0         1.0          124.8      -1.462260     2.997602e-14
# 7             7.0         1.1          116.2      -1.371511     9.992007e-15
# 8             7.0         1.2          131.8      -1.192131     2.975398e-14
# 9             7.0         1.3          164.2      -1.095933     1.021405e-14
# 10            7.0         1.4          163.6      -1.151062     2.997602e-14
# 11            7.0         1.5          163.6      -1.134569     9.992007e-15
# 12            7.0         1.6          113.6      -1.147834     0.000000e+00
# 13            7.0         1.7          137.8      -1.014588     9.769963e-15
# 14            7.0         1.8          162.8      -1.221194     9.992007e-15
# 15            7.0         1.9          139.0      -1.085457     1.998401e-14
# 16            7.0         2.0          136.8      -1.301339     0.000000e+00
# 17            8.0         0.6          164.4       0.011963     1.439994e-14
# 18            9.0         0.6          178.2      -1.670624     0.000000e+00
# 19           10.0         0.6          154.0      -0.527556     1.698641e-14
# 20           11.0         0.6          167.6      -0.606408     7.993606e-15
# 21           12.0         0.6          174.4      -1.762378     9.992007e-15
# 22           13.0         0.6          172.2       1.248413     9.769963e-15
# 23           14.0         0.6          176.4      -0.932085     1.199041e-14
# 24           15.0         0.6          172.8       3.579919     0.000000e+00
# 25            5.0         0.6           10.6      15.367240     1.399253e+01
# 26            6.0         0.6            8.8      16.362937     1.397950e+01
# 27            7.0         0.6            7.6      17.158241     1.418075e+01
# 28            7.0         0.7            7.4      17.581540     1.404177e+01
# 29            7.0         0.8            7.4      17.667868     1.381895e+01
# 30            7.0         0.9            7.4      17.660248     1.353306e+01
# 31            7.0         1.0            7.4      17.703168     1.381307e+01
# 32            7.0         1.1            7.4      17.672796     1.389958e+01
# 33            7.0         1.2            7.4      17.786308     1.368380e+01
# 34            7.0         1.3            7.4      17.827019     1.352267e+01
# 35            7.0         1.4            7.2      17.712877     1.327793e+01
# 36            7.0         1.5            7.4      17.697332     1.304206e+01
# 37            7.0         1.6            7.2      17.613605     1.342732e+01
# 38            7.0         1.7            7.2      17.581972     1.293948e+01
# 39            7.0         1.8            7.4      17.744345     1.341621e+01
# 40            7.0         1.9            7.2      17.696775     1.335362e+01
# 41            7.0         2.0            7.4      17.780573     1.336970e+01
# 42            8.0         0.6            6.6      17.832312     1.387009e+01
# 43            9.0         0.6            5.8      18.349252     1.400821e+01
# 44           10.0         0.6            5.2      18.895075     1.440354e+01
# 45           11.0         0.6            4.8      19.225772     1.431895e+01
# 46           12.0         0.6            4.4      19.649263     1.437928e+01
# 47           13.0         0.6            4.0      19.983442     1.449844e+01
# 48           14.0         0.6            3.8      20.302084     1.412948e+01
# 49           15.0         0.6            3.4      20.612281     1.446106e+01
